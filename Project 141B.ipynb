# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
plt.style.use('ggplot')
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# #### Reading the file

# %%
def reading_large_csv(x):
    
    '''to read csv files larger than 100,000 observations
    Input: file path (string)
    Output: pandas dataframe'''
    
    iter_csv = pd.read_csv(file_path, chunksize = 100000)
    df = pd.concat([chunk for chunk in iter_csv])
    
    # clean the columns, leave only the ones I want

# %% [markdown]
# ### 2011

# %%
file_path = "/Users/gvidal/Box Sync/Vet/Projects and Papers/2016 DHI/Data/DHI_downloads/Working_data/df_2011.csv"

# %%
iter_csv = pd.read_csv(file_path, chunksize = 100000)
df_2011 = pd.concat([chunk for chunk in iter_csv])

# %%
df_2011.shape
# Out:
# (3134951, 82)

# %%
print df_2011.ix[:,0:40].dtypes
# Out:
# Unnamed: 0                                    int64
# X.1                                           int64
# X                                             int64
# unique_COWID                                  int64
# SIRENAAB                                     object
# NETMERIT                                    float64
# DAMID                                        object
# BREED                                        object
# NETMERIT.1                                  float64
# BIRTHDAT                                    float64
# CONCEPTIONDAT                               float64
# DIMATCONCEPTIONIFLACTATING                  float64
# FRESHDAT                                    float64
# LACTATIONNUMBERWHENCALVEDRESPECTIVECOWID    float64
# HERDID                                        int64
# COUNTY                                       object
# HERDSIZE                                      int64
# COWID                                         int64
# ...

# %%
print df_2011.ix[:,40:].dtypes
# Out:
# PREVIOUSLACTLASTTESTDIM        float64
# PREVIOUSLACTLASTTESTFAT        float64
# PREVIOUSLACTLASTTESTPROT       float64
# PREVIOUSLACTLASTTESTSCC        float64
# PREVIOUSLACTLASTTESTMILKLTD    float64
# PREVIOUSLACTLASTTESTFATLTD     float64
# PREVIOUSLACTLASTTESTPROTLTD    float64
# PREVIOUSLACTLASTTESTSCCLTD     float64
# TOTALNUMDHIATESTCURRENTLACT      int64
# loop_number_test                 int64
# TESTDATE                         int64
# DIM                              int64
# MILK                           float64
# PCTFAT                         float64
# PCTPROT                        float64
# SCC                            float64
# SCC_cat                        float64
# DIM_cat                        float64
# birthdat_date                   object
# birthday_month                  object
# birthday_year                    int64
# freshdate_date                  object
# freshdate_month                 object
# freshdate_year                   int64
# ...

# %%
df_2011.drop(df_2011.columns[[0, 1, 2]], axis=1, inplace = True)

# %%
print df_2011.shape
# Out:
# (3134951, 79)

# %%
# change from number to object
# unique_COWID,

# %%
df_2011.describe(include = [np.number]).transpose()

# %%
df_2011.describe(include = ['O']).transpose()

# %% [markdown]
# ### 2012

# %%
file_path_2012 = "/Users/gvidal/Box Sync/Vet/Projects and Papers/2016 DHI/Data/DHI_downloads/Working_data/df_2012.csv"

iter_csv = pd.read_csv(file_path_2012, chunksize = 100000)
df_2012 = pd.concat([chunk for chunk in iter_csv])

# %%
print df_2012.shape
# Out:
# (3018663, 82)

# %%
#print df_2012.ix[:,0:40].dtypes

# %%
#print df_2012.ix[:,38:].dtypes

# %%
df_2012.drop(df_2012.columns[[0, 1, 2]], axis=1, inplace = True)

# %%
df_2012.shape
# Out:
# (3018663, 79)

# %% [markdown]
# ### 2013

# %%
file_path_2013 = "/Users/gvidal/Box Sync/Vet/Projects and Papers/2016 DHI/Data/DHI_downloads/Working_data/df_2013.csv"

iter_csv = pd.read_csv(file_path_2013, chunksize = 100000)
df_2013 = pd.concat([chunk for chunk in iter_csv])

# %%
print df_2013.shape
# Out:
# (2942064, 82)

# %%
#df_2013.ix[:,0:40].dtypes

# %%
#df_2013.ix[:,40:].dtypes

# %%
df_2013.drop(df_2013.columns[[0, 1, 2]], axis=1, inplace = True)

# %%
df_2013.shape
# Out:
# (2942064, 79)

# %% [markdown]
# ### 2014

# %%
file_path_2014 = "/Users/gvidal/Box Sync/Vet/Projects and Papers/2016 DHI/Data/DHI_downloads/Working_data/df_2014.csv"

iter_csv = pd.read_csv(file_path_2014, chunksize = 100000)
df_2014 = pd.concat([chunk for chunk in iter_csv])

# %%
print df_2014.shape
# Out:
# (3053926, 81)

# %%
#df_2014.ix[:,0:40].dtypes

# %%
#df_2014.ix[:,40:].dtypes

# %%
df_2014.drop(df_2014.columns[[0, 1]], axis=1, inplace = True)

# %%
df_2014.shape
# Out:
# (3053926, 79)

# %% [markdown]
# ### 2015

# %%
file_path_2015 = "/Users/gvidal/Box Sync/Vet/Projects and Papers/2016 DHI/Data/DHI_downloads/Working_data/df_2015.csv"

iter_csv = pd.read_csv(file_path_2015, chunksize = 100000)
df_2015 = pd.concat([chunk for chunk in iter_csv])
# Out:
# C:\Users\gvidal\AppData\Local\Continuum\Anaconda2\lib\site-packages\IPython\core\interactiveshell.py:2821: DtypeWarning: Columns (35,36,37) have mixed types. Specify dtype option on import or set low_memory=False.
#   if self.run_code(code, result):

# %% [markdown]
# Gives a waring message: columns 35, 36, 37 have mixed types. Specify dtype option on import or set low_memory = False

# %%
print df_2015.shape
# Out:
# (3055714, 80)

# %%
#df_2015.ix[:,0:40].dtypes

# %%
#df_2015.ix[:,40:].dtypes

# %%
df_2015.drop(df_2015.columns[[0, 1, 2]], axis=1, inplace = True)

# %%
df_2015.shape
# Out:
# (3055714, 77)

# %% [markdown]
# ### Combining together all the df

# %%
frame = [df_2011, df_2012, df_2013, df_2014]

# %%
# as double-check for merged dataframe
df_2011.shape[0] + df_2012.shape[0] + df_2013.shape[0] + df_2014.shape[0] #+ df_2015.shape[0]
# Out:
# 12149604

# %%
df2011_2014 = pd.concat(frame)

# %%
df2011_2014.shape
# Out:
# (12149604, 79)

# %% [markdown]
# ### Summary Statistics for Whole DataFrame

# %% [markdown]
# #### Continous Variables

# %%
#df2011_2014.describe(include = [np.number]).transpose()

# %% [markdown]
# #### Categorical Variables

# %%
#df2011_2014.describe(include = ['O']).transpose()

# %% [markdown]
# ### Plotting some variables

# %% [markdown]
# #### Scatterplot Matrix for Selected Variables

# %%
sns.pairplot(df2011_2014[['DIMATCONCEPTIONIFLACTATING', 'HERDSIZE', 'X305MEMILK', 'LACTNUM', 'FRESHDAT_IN_2011', 'TOTALTIMESBRED', 'SCC']], diag_kind = 'kde')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-26-4067704821ae> in <module>()
# ----> 1 sns.pairplot(df2011_2014[['DIMATCONCEPTIONIFLACTATING', 'HERDSIZE', 'X305MEMILK', 'LACTNUM', 'FRESHDAT_IN_2011', 'TOTALTIMESBRED']], diag_kind = 'kde')
#
# C:\Users\gvidal\AppData\Local\Continuum\Anaconda2\lib\site-packages\seaborn\linearmodels.pyc in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, size, aspect, dropna, plot_kws, diag_kws, grid_kws)
#    1620     if kind == "scatter":
#    1621         plot_kws.setdefault("edgecolor", "white")
# -> 1622         plotter(plt.scatter, **plot_kws)
#    1623     elif kind == "reg":
#    1624         plotter(regplot, **plot_kws)
#
# C:\Users\gvidal\AppData\Local\Continuum\Anaconda2\lib\site-packages\seaborn\axisgrid.pyc in map_offdiag(self, func, **kwargs)
#    1467
# ...

# %% [markdown]
# #### Histogram and Kernel Density

# %%
s = df2011_2014[['DIMATCONCEPTIONIFLACTATING']].values

print type(s)
# Out:
# <type 'numpy.ndarray'>

# %%
np.isnan(s)
# Out:
# array([[ True],
#        [ True],
#        [ True],
#        ...,
#        [ True],
#        [ True],
#        [ True]], dtype=bool)

# %%
s = s[~np.isnan(s)]

# %% [markdown]
# #### Histogram of Days in Milk at Conception if Lactating

# %%
sns.distplot(s)

# %% [markdown]
# #### Histogram X305 ME Merit

# %%
s = df2011_2014[['X305MEMILK']].values

# selecting non-NaN values from the np array
s = s[~np.isnan(s)]
sns.distplot(s)

# %% [markdown]
# #### Herd Size

# %%
s = df2011_2014[['HERDSIZE']].values

# selecting non-NaN values from the np array
s = s[~np.isnan(s)]
sns.distplot(s)

# %% [markdown]
# #### Total Times Bred

# %%
s = df2011_2014[['TOTALTIMESBRED']].values

# selecting non-NaN values from the np array
s = s[~np.isnan(s)]
sns.distplot(s)

# %% [markdown]
# #### Number of Cows By County

# %%
sns.countplot(x="COUNTY", data = df2011_2014)
#g.set_xticklabels(labels, rotation=30)

# %%
df2011_2014.boxplot(column = "HERDSIZE", by = "COUNTY", figsize = (10,8), rot = 55)
plt.show()

# %%
sns.boxplot(x = "LACTNUM", y = "COUNTY", data = df2011_2014, whis  =np.inf)

# %% [markdown]
# #### Somatic Cell Count by County

# %%
#sns.boxplot(x = "SCC", y = "COUNTY", data = df2011_2014, whis  =np.inf)

#sns.violinplot(x="COUNTY", y="SCC", data = df2011_2014, scale="width")

#sns.countplot(x="SCC_cat", data = df2011_2014)

df2011_2014.boxplot(column = "COUNTY", by = "SCC_cat", figsize = (10,8), rot = 50)
plt.show()

# %%
sns.countplot(x="conception_month", data = df2011_2014)

# %% [markdown]
# #### Fresh Date Month

# %%
sns.countplot(x="freshdate_month", data = df2011_2014)

# %% [markdown]
# #### Sold Date

# %%
sns.countplot(x="sold_month", data = df_2011, hue = "conception_month")

# %%
sns.lmplot('DIMATCONCEPTIONIFLACTATING', 'TOTALTIMESBRED', 
           data = df_2011,
           fit_reg = False)
#plt.title('Energy and Price by type of food')
#plt.xlabel('Price/Lb')
#plt.ylabel('Energy (kcal)')

# %%
df_2011.boxplot(column = "X305MEMILK", by = "COUNTY", figsize = (10,8), rot = 30)
plt.show()

# %%
df_2011.boxplot(column = "CONCEPTIONDAT", by = "COUNTY", figsize = (10,8), rot = 50)
plt.show()

# %% [markdown]
# ### Next Steps: get the georeferences for the farms and assign the county to work with the maps
